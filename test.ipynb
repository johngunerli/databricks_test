# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=6380032977278362#setting/sparkui/0306-032508-ej01p8na/driver-6764482747017579311">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
dbutils.fs.mounts()
# Out:
# Out[31]: [MountInfo(mountPoint='/databricks-datasets', source='databricks-datasets', encryptionType='sse-s3'),
#  MountInfo(mountPoint='/databricks/mlflow-tracking', source='databricks/mlflow-tracking', encryptionType='sse-s3'),
#  MountInfo(mountPoint='/databricks-results', source='databricks-results', encryptionType='sse-s3'),
#  MountInfo(mountPoint='/databricks/mlflow-registry', source='databricks/mlflow-registry', encryptionType='sse-s3'),
#  MountInfo(mountPoint='/', source='DatabricksRoot', encryptionType='sse-s3')]

# %%
dbutils.fs.ls('dbfs:/databricks-datasets/nyctaxi/')
# Out:
# Out[51]: [FileInfo(path='dbfs:/databricks-datasets/nyctaxi/readme_nyctaxi.txt', name='readme_nyctaxi.txt', size=916, modificationTime=1590473418000),
#  FileInfo(path='dbfs:/databricks-datasets/nyctaxi/reference/', name='reference/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/nyctaxi/sample/', name='sample/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/nyctaxi/tables/', name='tables/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/nyctaxi/taxizone/', name='taxizone/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/nyctaxi/tripdata/', name='tripdata/', size=0, modificationTime=0)]

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

df = spark.read.csv("dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2019-12.csv.gz", inferSchema=True, header=True)

# %%
df.show(5)
# Out:
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|congestion_surcharge|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+
# ...

# %%
from pyspark.sql.functions import col

# assuming the dataframe is called "nyctaxi_df"
nyctaxi_df = df.select(
    col("fare_amount"), 
    col("extra"), 
    col("mta_tax"), 
    col("tip_amount"), 
    col("total_amount"), 
    col("passenger_count")
)

# %%
nyctaxi_df.show()
# Out:
# +-----------+-----+-------+----------+------------+---------------+
# |fare_amount|extra|mta_tax|tip_amount|total_amount|passenger_count|
# +-----------+-----+-------+----------+------------+---------------+
# |       14.5|  3.0|    0.5|       0.0|        18.3|              1|
# |        2.5|  0.5|    0.5|       0.0|         3.8|              1|
# |        2.5|  0.5|    0.5|       0.0|         3.8|              1|
# |       28.5|  0.5|    0.5|      10.0|        39.8|              2|
# |        9.0|  3.0|    0.5|       0.0|        12.8|              2|
# |        6.5|  3.0|    0.5|       0.0|        10.3|              2|
# |       10.0|  3.0|    0.5|       0.0|        13.8|              0|
# |        4.0|  3.0|    0.5|      1.55|        9.35|              0|
# |        7.5|  3.0|    0.5|       0.0|        11.3|              0|
# |        5.5|  3.0|    0.5|      1.85|       11.15|              1|
# |       18.0|  3.0|    0.5|      4.35|       26.15|              3|
# ...
